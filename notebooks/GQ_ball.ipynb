# %%
import Q_balls
from Q_balls import Q_dless
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, legend, title, savefig
from matplotlib.font_manager import FontProperties
from IPython.display import display
from pylab import *

# %% [markdown]
# ### Different α fixed g

# %%
# Initial conditions
λ = 1e-5
w0 = .5, 0, 1, 0
r = 0, 100
n0 = Q_dless(w0, λ, r)
n0.sol()

# Initial conditions
λ = 1e-5
w0 = 2.5, 0, 1, 0
r = 0, 100
n1 = Q_dless(w0, λ, r)
n1.sol()

# Initial conditions
λ = 1e-5
w0 = 6, 0, 1, 0
r = 0, 100

n2 = Q_dless(w0, λ, r)
n2.sol()

# Initial conditions
λ = 1e-5
w0 = 10, 0, 1, 0
r = 0, 100

n3 = Q_dless(w0, λ, r)
n3.sol()

# Initial conditions
λ = 1e-5
w0 = 13, 0, 1, 0
r = 0, 100

n4 = Q_dless(w0, λ, r)
n4.sol()

# Initial conditions
λ = 1e-5
w0 = 19, 0, 1, 0
r = 0, 100

n5 = Q_dless(w0, λ, r)
n5.sol()

# Initial conditions
λ = 1e-5
w0 = 25, 0, 1, 0
r = 0, 100

n6 = Q_dless(w0, λ, r)
n6.sol()

# %%
plt.plot(n0.rn, n0.α, label = 'α(0) = 0.5')
plt.plot(n1.rn, n1.α, label = 'α(0) = 2.5')
plt.plot(n2.rn, n2.α,   label =   'α(0) = 7')
plt.plot(n3.rn, n3.α, label = 'α(0) = 10')
plt.plot(n4.rn, n4.α, label = 'α(0) = 13')
plt.plot(n5.rn, n5.α, label = 'α(0) = 19')
plt.plot(n6.rn, n6.α, label = 'α(0) = 25')
plt.text(5, .51,'$0π$')
plt.text(5, 3.7,'$π$')
plt.text(5, 6.8,'$2π$')
plt.text(5, 10,'$3π$')
plt.text(5, 13,'$4π$')
plt.text(5, 19.5,'$6π$')
plt.text(5, 25.5,'$8π$')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([0, 10])
plt.ylim([-1, 28])
plt.title('α(r) for different α(0) but fixed g(0)=1')
plt.legend(loc='upper right')
#plt.show()
plt.savefig('a_init.png', dpi =1000)

# %%
plt.plot(n0.rn, n0.g, label = 'α(0) = 0.5')
plt.plot(n1.rn, n1.g, label = 'α(0) = 2.5')
plt.plot(n2.rn, n2.g,   label =   'α(0) = 7')
plt.plot(n3.rn, n3.g, label = 'α(0) = 10')
plt.plot(n4.rn, n4.g, label = 'α(0) = 13')
plt.plot(n5.rn, n5.g, label = 'α(0) = 19')
plt.plot(n6.rn, n6.g, label = 'α(0) = 25')
#plt.text(5, .51,'$0π$')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([0, 10])
#plt.ylim([0.86, 2])
plt.title('g(r) for different α(0) but fixed g(0)=1')
plt.legend(loc='best')
#plt.show()
plt.savefig('g.png', dpi =1000)

# %%
plt.yscale('log')
plt.plot(n0.rn, n0.E(), label = 'α(0) = 0.5')
plt.plot(n2.rn, n2.E(),   label =   'α(0) = 7')
#plt.plot(n3.rn, n3.E(), label = 'α(0) = 10')
plt.plot(n4.rn, n4.E(), label = 'α(0) = 13')
plt.plot(n5.rn, n5.E(), label = 'α(0) = 19')
plt.plot(n6.rn, n6.E(), label = 'α(0) = 25')
#plt.text(5, .51,'$0π$')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([0, 10])
plt.ylim([0.1, 1e5])
plt.title('$E_{gauged}$ for different α(0) but fixed g(0)=1')
plt.legend(loc='best')
#plt.show()
plt.savefig('E.png', dpi =1000)

# %%
plt.plot(n0.rn, n0.ED(),   label =   'α(0) = 0.5')
plt.plot(n2.rn, n2.ED(),   label =   'α(0) = 7')
#plt.plot(n3.rn, n3.E(), label = 'α(0) = 10')
plt.plot(n4.rn, n4.ED(), label = 'α(0) = 13')
plt.plot(n5.rn, n5.ED(), label = 'α(0) = 19')
plt.plot(n6.rn, n6.ED(), label = 'α(0) = 25')
#plt.text(5, .51,'$0π$')
plt.xlabel('$r$', fontsize=22)
plt.xlim([0, 40])
plt.ylim([0, 2e4])
plt.title('Energy density for different α(0) but fixed g(0)=1')
plt.legend(loc='best')
#plt.show()
plt.savefig('E_dens.png', dpi =1000)

# %%
plt.plot(n0.rn, n0.QD(),   label =   'α(0) = 0.5')
plt.plot(n2.rn, n2.QD(),   label =   'α(0) = 7')
#plt.plot(n3.rn, n3.E(), label = 'α(0) = 10')
plt.plot(n4.rn, n4.QD(), label = 'α(0) = 13')
plt.plot(n5.rn, n5.QD(), label = 'α(0) = 19')
plt.plot(n6.rn, n6.QD(), label = 'α(0) = 25')
#plt.text(5, .51,'$0π$')
plt.xlabel('$r$', fontsize=22)
plt.xlim([0, 30])
#plt.ylim([0, 2e4])
plt.title('Charge density for different α(0) but fixed g(0)=1')
plt.legend(loc='best')
#plt.show()
plt.savefig('Q_dens.png', dpi =1000)

# %%
plt.yscale('log')
plt.axhline(y=np.pi/4, color='black', linestyle='--')
plt.plot(n0.rn, n0.Q(),   label =   'α(0) = 0.5')
plt.plot(n2.rn, n2.Q(),   label =   'α(0) = 7')
#plt.plot(n3.rn, n3.E(), label = 'α(0) = 10')
plt.plot(n4.rn, n4.Q(), label = 'α(0) = 13')
plt.plot(n5.rn, n5.Q(), label = 'α(0) = 19')
plt.plot(n6.rn, n6.Q(), label = 'α(0) = 25')
plt.text(51, .9,'$π/4$')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([0, 10])
plt.ylim([.0001, 4])
plt.title('$Q_{gauged}$ for different α(0) but fixed g(0)=1')
plt.legend(loc='best')
#plt.show()
plt.savefig('Q.png', dpi =1000)

# %%
plt.loglog(n0.E(), n0.Q(), label = 'α(0) = 0.5')
#plt.loglog(n2.E(), n2.Q(), label = 'α(0) = 7')
#plt.loglog(n4.E(), n4.Q(), label = 'α(0) = 0.5')
plt.loglog(n6.E(), n6.Q(), label = 'α(0) = 25')
#plt.text(100,1, 'Q')
plt.xlim([1e-1,2e5])
plt.ylim([1e-6,1e0])
plt.xlabel('$Q_{gauged}$', fontsize=15)
plt.ylabel('$E_{gauged}$', fontsize=15)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Fixed α different g

# %%
# Initial conditions
λ = 1e-5 
w0 = 13, 0, .1, 0
r = 0, 100
m1 = Q_dless(w0, λ, r)
m1.sol()

# Initial conditions
λ = 1e-5
w0 = 13, 0, 1, 0
r = 0, 100

m2 = Q_dless(w0, λ, r)
m2.sol()

# Initial conditions
λ = 1e-5
w0 = 13, 0, 2, 0
r = 0, 100

m3 = Q_dless(w0, λ, r)
m3.sol()

# Initial conditions
λ = 1e-5
w0 = 13, 0, 3, 0
r = 0, 100

m4 = Q_dless(w0, λ, r)
m4.sol()

# %%
plt.plot(m1.rn, m1.α, label = 'g(0) = 0.1')
plt.plot(m2.rn, m2.α, label = 'g(0) = 1')
plt.plot(m3.rn, m3.α, label = 'g(0) = 2')
plt.plot(m4.rn, m4.α, label = 'g(0) = 3')
#plt.text(5, .51,'$0π$')
plt.text(40, 15.86,'$5π$')
plt.text(40, 12.7,'$4π$')
plt.text(40, 14.3,'$9π/2$')
plt.xlabel('$r$', fontsize=22)
plt.xlim([0, 80])
#plt.ylim([-1, 28])
plt.title('α(r) for fixed α(0) = 13 but different g(0)')
plt.legend(loc='center right')
#plt.show()
plt.savefig('a1.png', dpi =1000)

# %%
#plt.plot(m1.rn, m1.g, label = 'g(0) = 0.1')
plt.plot(m2.rn, m2.g, color = 'orange', label = 'g(0) = 1')
plt.plot(m3.rn, m3.g, color='green', label = 'g(0) = 2')
#plt.plot(m4.rn, m4.g, label = 'g(0) = 3')
#plt.text(5, .51,'$0π$')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([0, 8])
#plt.ylim([-1, 28])
plt.title('g(r) for fixed α(0) = 13 but different g(0)')
plt.legend(loc='best')
#plt.show()
plt.savefig('g1.png', dpi =1000)

# %%
plt.yscale('log')
#plt.plot(m1.rn, m1.E(), label = 'g(0) = 0.1')
plt.plot(m2.rn, m2.E(), color='orange', label = 'g(0) = 1')
plt.plot(m3.rn, m3.E(), color ='green', label = 'g(0) = 2')
#plt.plot(m4.rn, m4.E(), label = 'g(0) = 3')
#plt.text(5, .51,'$0π$')
plt.xlabel('$r$', fontsize=22)
plt.ylim([0.1, 1e5])
#plt.ylim([-1, 28])
plt.title('$E_{gauged}$ for fixed α(0) = 13 but different g(0)')
plt.legend(loc='center right')
#plt.show()
plt.savefig('E1.png', dpi =1000)

# %%
plt.yscale('log')
plt.axhline(y=np.pi/4, color='black', linestyle='--')
plt.plot(m1.rn, m1.Q(), label = 'g(0) = 0.1')
plt.plot(m2.rn, m2.Q(), label = 'g(0) = 1')
plt.plot(m3.rn, m3.Q(), label = 'g(0) = 2')
plt.plot(m4.rn, m4.Q(), label = 'g(0) = 3')
plt.text(51, .9,'$π/4$')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([0, 10])
plt.ylim([.0001, 20])
plt.title('$Q_{gauged}$ for fixed α(0) = 13 but different g(0)')
plt.legend(loc='best')
#plt.show()
plt.savefig('Q1.png', dpi =1000)

# %% [markdown]
# ### Different $\lambda$

# %%
# Initial conditions
λ = 1e-5 
w0 = 13, 0, 1, 0
r = 0, 100
l1 = Q_dless(w0, λ, r)
l1.sol()

# Initial conditions
λ = 1e-6
w0 = 13, 0, 1, 0
r = 0, 100

l2 = Q_dless(w0, λ, r)
l2.sol()

# Initial conditions
λ = 1e-7
w0 = 13, 0, 1, 0
r = 0, 100

l3 = Q_dless(w0, λ, r)
l3.sol()

# Initial conditions
λ = 1e-8
w0 = 13, 0, 1, 0
r = 0, 100

l4 = Q_dless(w0, λ, r)
l4.sol()

# %%
plt.plot(l1.rn, l1.α, label = 'λ = $10^{-5}$')
plt.plot(l2.rn, l2.α, label = 'λ = $10^{-6}$')
plt.plot(l3.rn, l3.α, label = 'λ = $10^{-7}$')
plt.plot(l4.rn, l4.α, label = 'λ = $10^{-8}$')
#plt.text(40, 12.6,'$4π$')
plt.xlabel('$r$', fontsize=22)
plt.xlim([0, 80])
#plt.ylim([-1, 28])
plt.title('α(r) for fixed α(0) and g(0) but different λ')
plt.legend(loc='center right')
#plt.show()
plt.savefig('a2.png', dpi =1000)

# %%
plt.plot(l1.rn, l1.g, label = 'λ = $10^{-5}$')
plt.plot(l2.rn, l2.g, label = 'λ = $10^{-6}$')
plt.plot(l3.rn, l3.g, label = 'λ = $10^{-7}$')
plt.plot(l4.rn, l4.g, label = 'λ = $10^{-8}$')
#plt.text(40, 12.6,'$4π$')
plt.xlabel('$r$', fontsize=22)
plt.xlim([0, 30])
plt.ylim([0.9, 1.5])
plt.title('g(r) for fixed α(0) and g(0) but different λ')
plt.legend(loc='center right')
#plt.show()
plt.savefig('g2.png', dpi =1000)

# %%
plt.yscale('log')
plt.plot(l1.rn, l1.E(), label = 'λ = $10^{-5}$')
plt.plot(l2.rn, l2.E(), label = 'λ = $10^{-6}$')
plt.plot(l3.rn, l3.E(), label = 'λ = $10^{-7}$')
plt.plot(l4.rn, l4.E(), label = 'λ = $10^{-8}$')
#plt.text(40, 12.6,'$4π$')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([0, 30])
plt.ylim([0.01, 1e5])
plt.title('$E_{gauged}$ for fixed α(0) and g(0) but different λ')
plt.legend(loc='best')
#plt.show()
plt.savefig('E2.png', dpi =1000)

# %%
plt.yscale('log')
plt.axhline(y=np.pi/4, color='black', linestyle='--')
plt.plot(l1.rn, l1.Q(), label = 'λ = $10^{-5}$')
plt.plot(l2.rn, l2.Q(), label = 'λ = $10^{-6}$')
plt.plot(l3.rn, l3.Q(), label = 'λ = $10^{-7}$')
plt.plot(l4.rn, l4.Q(), label = 'λ = $10^{-8}$')
plt.text(51, 1.3,'$π/4$')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([0, 10])
plt.ylim([1E-10, 10])
plt.title('$Q_{gauged}$ for fixed α(0) and g(0) but different λ')
plt.legend(loc='lower right')
#plt.show()
plt.savefig('Q2.png', dpi =1000)
