# %% [markdown]
# # Gauged Q-ball

# %%
import Q_balls
from Q_balls import Q_class
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, legend, title, savefig
from matplotlib.font_manager import FontProperties
from IPython.display import display
from pylab import *

# %% [markdown]
# $\alpha' = x; \,\,\\
# x' = -\frac{2}{r}x+ \frac{1}{(1-\lambda g^{2} \sin^{2} \alpha)} \left[ 2\lambda g x y \sin^{2}\alpha  -\frac{g^{2}}{2}\sin 2\alpha (1-\lambda x^{2}) +4 m^{2} \sin \alpha \right]; \,\,\\
# g'=y; \,\,\\
# y'= -\frac{2}{r}y+ 4K g \sin^{2}\alpha (1+\lambda x^{2}) $

# %%
λ, M = 1, 1
# Initial conditions
w0 = 7, 0, 5, 0
r = 0, 100

Q1 = Q_class(w0, M, λ, r)
Q1.Num_sol()

# %%
λ, M = .73, 1
# Initial conditions
w0 = 7, 0, 5, 0
r = 0, 100

Q2 = Q_class(w0, M, λ, r)
Q2.Num_sol()

# %%
λ, M = .073, 1
# Initial conditions
w0 = 7, 0, 5, 0
r = 0, 100

Q3 = Q_class(w0, M, λ, r)
Q3.Num_sol()

# %%
λ, M = .0073, 1
# Initial conditions
w0 = 7, 0, 5, 0
r = 0, 100

Q4 = Q_class(w0, M, λ, r)
Q4.Num_sol()

# %%
λ, M = .00073, 1
# Initial conditions
w0 = 7, 0, 5, 0
r = 0, 100

Q5 = Q_class(w0, M, λ, r)
Q5.Num_sol()

# %%
λ, M = .0073, 1
# Initial conditions
w0 = 2, 0, 5, 0
r = 0, 100

Q6 = Q_class(w0, M, λ, r)
Q6.Num_sol()

# %%
λ, M = .000073, 1
# Initial conditions
w0 = 7, 0, 5, 0
r = 0, 100

Q7 = Q_class(w0, M, λ, r)
Q7.Num_sol()

# %%
plt.plot(Q3.rn, Q3.α, label = 'λ = 0.073')
plt.plot(Q4.rn, Q4.α, label = 'λ = 0.0073')
plt.plot(Q5.rn, Q5.α, label = 'λ = 0.00073')
#plt.text(101, 6.28,'$2π$')
#plt.plot(Q5.rn, Q5.g, label = 'g')
#plt.plot(r, y2_sol, label = 'g')
plt.xlim([0, 4])
#plt.ylim([-0, 2.0])
plt.xlabel('$r$', fontsize=22)
plt.title('α(r) with α(0)=7')
plt.legend(loc='best')
#plt.show()
plt.savefig('a(r).png', dpi =1000)

# %%
plt.plot(Q1.rn, Q1.α, '--', label = 'λ = 1')
plt.plot(Q2.rn, Q2.α, '--', label = 'λ = 0.73')
plt.plot(Q1.rn, Q1.g, label = 'λ = 1')
plt.plot(Q2.rn, Q2.g, label = 'λ = 0.73')
plt.text(35, 7.5,'$5π/2$')
#plt.plot(Q5.rn, Q5.g, label = 'g')
#plt.plot(r, y2_sol, label = 'g')
plt.xlim([.0, 40])
plt.ylim([4, 10])
plt.xlabel('$r$', fontsize=22)
plt.title('Unstable solutions - α (dashed) and g (solid)')
plt.legend(loc='best')
#plt.show()
plt.savefig('unstable.png', dpi =1000)

# %%
plt.yscale('log')
plt.plot(Q3.rn, Q3.g, label = 'λ = 0.073')
plt.plot(Q4.rn, Q4.g, label = 'λ = 0.0073')
plt.plot(Q5.rn, Q5.g, label = 'λ = 0.00073')
#plt.plot(Q5.rn, Q5.g, label = 'g')
#plt.plot(r, y2_sol, label = 'g')
#plt.xlim([.0, 40])
#plt.ylim([1, 180])
plt.xlabel('$r$', fontsize=22)
plt.title('g(r) with g(0)=5')
plt.legend(loc='best')
#plt.show()
plt.savefig('g(r).png', dpi =1000)

# %%
plt.yscale('log')
plt.plot(Q5.rn, Q5.g, label = 'λ = 0.00073')
#plt.xlabel('$r$', fontsize=22)
#plt.title('g(r) with g(0)=5')
#plt.legend(loc='best')
plt.show()

# %%
plt.plot(Q1.rn, Q1.ED(), label = 'λ = 1')
plt.plot(Q2.rn, Q2.ED(), label = 'λ = 0.73')
plt.plot(Q1.rn, Q1.QD(), '--', label = 'λ = 1',)
plt.plot(Q2.rn, Q2.QD(), '--', label = 'λ = 0.73')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([.0, 40])
plt.ylim([.0, 1e12])
plt.title('Energy (solid) and Charge (dashed) densities')
plt.legend(loc='best')
#plt.show()
plt.savefig('div_dens.png', dpi =1000)

# %%
plt.plot(Q3.rn, Q3.ED(), label = 'λ = 0.073')
plt.plot(Q4.rn, Q4.ED(), label = 'λ = 0.0073')
plt.plot(Q5.rn, Q5.ED(), label = 'λ = 0.00073')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([-1, 40])
plt.ylim([.0, 1e2])
plt.title('Energy density')
plt.legend(loc='best')
#plt.show()
plt.savefig('E_dens.png', dpi =1000)

# %%
plt.yscale('log')
plt.plot(Q3.rn, Q3.E(), label = 'λ = 0.073')
plt.plot(Q4.rn, Q4.E(), label = 'λ = 0.0073')
plt.plot(Q5.rn, Q5.E(), label = 'λ = 0.00073')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([.0, 40])
plt.ylim([1e-3, 1e7])
plt.title('$E_{gauged}$')
plt.legend(loc='best')
#plt.show()
plt.savefig('E.png', dpi =1000)

# %%
plt.plot(Q3.rn, Q3.QD(), label = 'λ = 0.073')
plt.plot(Q4.rn, Q4.QD(), label = 'λ = 0.0073')
plt.plot(Q5.rn, Q5.QD(), label = 'λ = 0.00073')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([.0, 10])
#plt.ylim([.0, 3e1])
plt.title('Charge density')
plt.legend(loc='best')
plt.savefig('Q_dens.png', dpi =1000)
#plt.show()

# %%
plt.yscale('log')
plt.plot(Q3.rn, Q3.Q(), label = 'λ = 0.073')
plt.plot(Q4.rn, Q4.Q(), label = 'λ = 0.0073')
plt.plot(Q5.rn, Q5.Q(), label = 'λ = 0.00073')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([.0, 40])
plt.ylim([1e-3, 1e5])
plt.title('$Q_{gauged}$')
plt.legend(loc='best')
#plt.show()
plt.savefig('Q.png', dpi =1000)

# %%
#plt.xscale('log')
#plt.yscale('log')
plt.loglog(Q3.E(), Q3.Q(), label = 'λ = 0.073')
plt.loglog(Q4.E(), Q4.Q(), label = 'λ = 0.0073')
plt.loglog(Q5.E(), Q5.Q(), label = 'λ = 0.00073')
#plt.text(100,1, 'Q')
#plt.xlim([1e-20,1e-19])
#plt.ylim([1e-20,1e-19])
plt.xlabel('$Q_{gauged}$', fontsize=15)
plt.ylabel('$E_{gauged}$', fontsize=15)
plt.legend(loc='best')
#plt.show()
plt.savefig('QVsE.png', dpi =1000)

# %% [markdown]
# ### Different initial conditions

# %%
λ, M = 0.0073, 1
# Initial conditions
w0 = 1, 0, 2, 0
r = 0, 100

Qi1 = Q_class(w0, M, λ, r)
Qi1.Num_sol()

# %%
λ, M = 0.0073, 1
# Initial conditions
w0 = 2.5, 0, 4, 0
r = 0, 100

Qi2 = Q_class(w0, M, λ, r)
Qi2.Num_sol()

# %%
λ, M = 0.0073, 1
# Initial conditions
w0 = 13, 0, 10, 0
r = 0, 100

Qi3 = Q_class(w0, M, λ, r)
Qi3.Num_sol()

# %%
λ, M = 0.0073, 1
# Initial conditions
w0 = 10, 0, 7, 0
r = 0, 100

Qi4 = Q_class(w0, M, λ, r)
Qi4.Num_sol()

# %%
λ, M = 0.0073, 1
# Initial conditions
w0 = 19, 0, 11, 0
r = 0, 100

T11 = Q_class(w0, M, λ, r)
T11.Num_sol()

# %%
λ, M = 0.0073, 1
# Initial conditions
w0 = 26, 0, 15, 0
r = 0, 100

T12 = Q_class(w0, M, λ, r)
T12.Num_sol()

# %%
#plt.plot(Qi1.rn, Qi1.α, label = 'α(0) = 1,   g(0) = 2')
plt.plot(Qi2.rn, Qi2.α, label = 'α(0) = 2.5, g(0) = 4')
plt.plot(Q4.rn, Q4.α,   label =   'α(0) = 7,   g(0) = 5')
plt.plot(Qi4.rn, Qi4.α, label = 'α(0) = 10,  g(0) = 7')
plt.plot(Qi3.rn, Qi3.α, label = 'α(0) = 13,  g(0) =10')
plt.plot(T11.rn, T11.α, label = 'α(0) = 17,  g(0) =11')
plt.plot(T12.rn, T12.α, label = 'α(0) = 26,  g(0) =15')
#plt.text(5, .51,'$0π$')
plt.text(5, 3.7,'$π$')
plt.text(5, 6.8,'$2π$')
plt.text(5, 10,'$3π$')
plt.text(5, 13,'$4π$')
plt.text(5, 19.5,'$6π$')
plt.text(5, 25.5,'$8π$')
plt.xlabel('$r$', fontsize=22)
plt.xlim([0, 30])
#plt.ylim([-1, 22])
plt.title('α(r) for different initial values')
plt.legend(loc='upper right')
#plt.show()
plt.savefig('a_init.png', dpi =1000)

# %%
#plt.plot(Qi1.rn, Qi1.g, label = 'α(0) = 1,   g(0) = 2')
plt.plot(Qi2.rn, Qi2.g, label = 'α(0) = 2.5, g(0) = 4')
plt.plot(Q4.rn, Q4.g,   label =   'α(0) = 7,   g(0) = 5')
plt.plot(Qi4.rn, Qi4.g, label = 'α(0) = 10,  g(0) = 7')
plt.plot(Qi3.rn, Qi3.g, label = 'α(0) = 13,  g(0) =10')
plt.plot(T11.rn, T11.g, label = 'α(0) = 17,  g(0) =11')
plt.plot(T12.rn, T12.g, label = 'α(0) = 26,  g(0) =15')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([0, 100])
plt.ylim([1, 17])
plt.title('g(r) for different initial values')
plt.legend(loc='lower right')
#plt.show()
plt.savefig('g_init.png', dpi =1000)

# %%
plt.yscale('log')
#plt.plot(Qi2.rn, Qi2.E(), label = 'α(0) = 2.5, g(0) = 4')
plt.plot(Q4.rn, Q4.E(),   label =   'α(0) = 7,   g(0) = 5')
#plt.plot(Qi4.rn, Qi4.E(), label = 'α(0) = 10,  g(0) = 7')
plt.plot(Qi3.rn, Qi3.E(), label = 'α(0) = 13,  g(0) =10')
plt.plot(T11.rn, T11.E(), label = 'α(0) = 17,  g(0) =11')
#plt.plot(T12.rn, T12.E(), label = 'α(0) = 26,  g(0) =15')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([0, 30])
plt.ylim([1e-1, 1e4])
plt.title('$E_{gauged}$')
plt.legend(loc='lower right')
#plt.show()
plt.savefig('Ediff.png', dpi =1000)

# %%
plt.yscale('log')
#plt.plot(Qi2.rn, Qi2.E(), label = 'α(0) = 2.5, g(0) = 4')
plt.plot(Q4.rn, Q4.Q(),   label =   'α(0) = 7,   g(0) = 5')
#plt.plot(Qi4.rn, Qi4.E(), label = 'α(0) = 10,  g(0) = 7')
plt.plot(Qi3.rn, Qi3.Q(), label = 'α(0) = 13,  g(0) =10')
plt.plot(T11.rn, T11.Q(), label = 'α(0) = 17,  g(0) =11')
#plt.plot(T12.rn, T12.E(), label = 'α(0) = 26,  g(0) =15')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([0, 30])
plt.ylim([1e-1, 1e3])
plt.title('$Q_{gauged}$')
plt.legend(loc='lower right')
#plt.show()
plt.savefig('Qdiff.png', dpi =1000)

# %%
λ, M = 0.073, 1
# Initial conditions
w0 = 7, 0, 7, 0
r = 0, 100

k = Q_class(w0, M, λ, r)
k.Num_sol()

# %%
λ, M = 0.0073, 1
# Initial conditions
w0 = 38, 0, 38, 0
r = 0, 100

k1 = Q_class(w0, M, λ, r)
k1.Num_sol()

# %%
plt.plot(k1.rn, k1.Q())
#plt.xlim([0, 30])
plt.ylim([0, 0.781])
plt.ylabel('$Q_{gauged}(r)$', fontsize=15)
plt.xlabel('r', fontsize=22)
plt.title('$Q_{gauged}^{\infty}<\pi/4$')
#plt.legend(loc='best')
#plt.show()
plt.savefig('QB.png', dpi =1000)

# %%
plt.plot(k1.rn, k1.E())
plt.xlabel('$r$', fontsize=22)
#plt.xlim([0, 30])
#plt.ylim([-1, 14])
plt.title('$E_{gauged}$')
#plt.legend(loc='upper right')
#plt.show()
plt.savefig('Eb.png', dpi =1000)

# %%
λ, M = 0.073, 1
# Initial conditions
w0 = 37, 0, 20, 0
r = 0, 100

k2 = Q_class(w0, M, λ, r)
k2.Num_sol()

# %%
plt.plot(k2.rn, k2.α, label = 'α(0) = 27, g(0) = 5')
#plt.xlim([0, 30])
#plt.ylim([1, 60])
#plt.title('g(r) for different initial values')
plt.legend(loc='best')
plt.show()

# %%
λ, M = 0.0073, 6
# Initial conditions
w0 = 7, 0, 5, 0
r = 0, 100

kt = Q_class(w0, M, λ, r)
kt.Num_sol()

# %%
plt.plot(kt.rn, kt.E(), label = 'α(0) = 27, g(0) = 5')
#plt.xlim([0, 30])
#plt.ylim([1, 60])
#plt.title('g(r) for different initial values')
plt.legend(loc='best')
plt.show()
