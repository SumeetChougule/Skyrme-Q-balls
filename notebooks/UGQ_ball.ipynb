# %%
import Q_balls
from Q_balls import UQ_dless
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, legend, title, savefig
from matplotlib.font_manager import FontProperties
from IPython.display import display
from pylab import *

# %%
# Initial conditions
λ, w = 1e-5, 1
i = .5, 0
r = 0, 100
n0 = UQ_dless(i, w, λ, r)
n0.Num_sol()

# Initial conditions
λ, w = 1e-5, 1
i = 2.5, 0
r = 0, 100
n1 = UQ_dless(i, w, λ, r)
n1.Num_sol()

# Initial conditions
λ, w = 1e-5, 1
i = 7, 0
r = 0, 100
n2 = UQ_dless(i, w, λ, r)
n2.Num_sol()

# Initial conditions
λ, w = 1e-5, 1
i = 10, 0
r = 0, 100
n3 = UQ_dless(i, w, λ, r)
n3.Num_sol()

# Initial conditions
λ, w = 1e-5, 1
i = 13, 0
r = 0, 100
n4 = UQ_dless(i, w, λ, r)
n4.Num_sol()

# Initial conditions
λ, w = 1e-5, 1
i = 19, 0
r = 0, 100
n5 = UQ_dless(i, w, λ, r)
n5.Num_sol()

# Initial conditions
λ, w = 1e-5, 1
i = 25, 0
r = 0, 100
n6 = UQ_dless(i, w, λ, r)
n6.Num_sol()

# %%
plt.plot(n0.rn, n0.α, label = 'α(0) = 0.5')
plt.plot(n1.rn, n1.α, label = 'α(0) = 2.5')
plt.plot(n2.rn, n2.α,   label =   'α(0) = 7')
plt.plot(n3.rn, n3.α, label = 'α(0) = 10')
plt.plot(n4.rn, n4.α, label = 'α(0) = 13')
plt.plot(n5.rn, n5.α, label = 'α(0) = 19')
plt.plot(n6.rn, n6.α, label = 'α(0) = 25')
plt.text(5, .51,'$0π$')
plt.text(5, 3.7,'$π$')
plt.text(5, 6.8,'$2π$')
plt.text(5, 10,'$3π$')
plt.text(5, 13,'$4π$')
plt.text(5, 19.5,'$6π$')
plt.text(5, 25.5,'$8π$')
plt.xlabel('$r$', fontsize=22)
plt.xlim([0, 30])
plt.ylim([-1, 28])
plt.title('α(r) for different α(0) but fixed $\omega=1$')
plt.legend(loc='upper right')
#plt.show()
plt.savefig('au.png', dpi =1000)

# %%
plt.yscale('log')
plt.plot(n0.rn, n0.E(), label = 'α(0) = 0.5')
#plt.plot(n2.rn, n2.E(),   label =   'α(0) = 7')
#plt.plot(n3.rn, n3.E(), label = 'α(0) = 10')
plt.plot(n4.rn, n4.E(), label = 'α(0) = 13')
plt.plot(n5.rn, n5.E(), label = 'α(0) = 19')
plt.plot(n6.rn, n6.E(), label = 'α(0) = 25')
#plt.text(5, .51,'$0π$')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([0, 10])
plt.ylim([1, 1e5])
plt.title('$E_{gauged}$ for different α(0) but fixed $\omega=1$')
plt.legend(loc='best')
#plt.show()
plt.savefig('Eu.png', dpi =1000)

# %%
plt.yscale('log')
plt.axhline(y=np.pi/4, color='black', linestyle='--')
plt.plot(n0.rn, n0.Q(), label = 'α(0) = 0.5')
#plt.plot(n2.rn, n2.E(),   label =   'α(0) = 7')
#plt.plot(n3.rn, n3.E(), label = 'α(0) = 10')
plt.plot(n4.rn, n4.Q(), label = 'α(0) = 13')
plt.plot(n5.rn, n5.Q(), label = 'α(0) = 19')
plt.plot(n6.rn, n6.Q(), label = 'α(0) = 25')
#plt.text(5, .51,'$0π$')
plt.text(51, .99,'$π/4$')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([0, 40])
plt.ylim([0.0001, 1e1])
plt.title('$Q_{gauged}$ for different α(0) but fixed $\omega=1$')
plt.legend(loc='best')
#plt.show()
plt.savefig('Qu.png', dpi =1000)

# %%
λ, w = 1e-5, 2
i = 7, 0
r = 0, 100
n7 = UQ_dless(i, w, λ, r)
n7.Num_sol()

plt.plot(n7.rn, n7.α, label = 'α(0) = 0.5')
#plt.text(5, .51,'$0π$')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([0, 40])
#plt.ylim([0.0001, 1e1])
#plt.title('$Q_{gauged}$ for different α(0) but fixed g(0)=1')
plt.legend(loc='best')
plt.show()

# %%
plt.plot(n0.rn, n0.QD(), label = 'α(0) = 0.5')
#plt.plot(n2.rn, n2.E(),   label =   'α(0) = 7')
#plt.plot(n3.rn, n3.E(), label = 'α(0) = 10')
plt.plot(n4.rn, n4.QD(), label = 'α(0) = 13')
plt.plot(n5.rn, n5.QD(), label = 'α(0) = 19')
plt.plot(n6.rn, n6.QD(), label = 'α(0) = 25')
#plt.text(5, .51,'$0π$')
#plt.text(51, .99,'$π/4$')
plt.xlabel('$r$', fontsize=22)
plt.xlim([0, 30])
#plt.ylim([0.0001, 1e1])
plt.title('Charge density for different α(0) but fixed $\omega=1$')
plt.legend(loc='best')
#plt.show()
plt.savefig('QDu.png', dpi =1000)

# %%
plt.plot(n0.rn, n0.ED(), label = 'α(0) = 0.5')
#plt.plot(n2.rn, n2.E(),   label =   'α(0) = 7')
#plt.plot(n3.rn, n3.E(), label = 'α(0) = 10')
plt.plot(n4.rn, n4.ED(), label = 'α(0) = 13')
plt.plot(n5.rn, n5.ED(), label = 'α(0) = 19')
plt.plot(n6.rn, n6.ED(), label = 'α(0) = 25')
#plt.text(5, .51,'$0π$')
#plt.text(51, .99,'$π/4$')
plt.xlabel('$r$', fontsize=22)
plt.xlim([0, 30])
plt.ylim([0, 2e4])
plt.title('Energy density for different α(0) but fixed $\omega=1$')
plt.legend(loc='best')
#plt.show()
plt.savefig('EDu.png', dpi =1000)

# %%
# Initial conditions
λ,  w = 1e-5, 1 
i = 19, 1
r = 0, 100
m1 = UQ_dless(i, w, λ, r)
m1.Num_sol()

# Initial conditions
λ,  w = 1e-5, 3 
i = 19, 0
r = 0, 100
m2 = UQ_dless(i, w, λ, r)
m2.Num_sol()

# Initial conditions
λ,  w = 1e-5, 7 
i = 19, 0
r = 0, 100
m3 = UQ_dless(i, w, λ, r)
m3.Num_sol()

# Initial conditions
λ,  w = 1e-5, 9 
i = 19, 0
r = 0, 100
m4 = UQ_dless(i, w, λ, r)
m4.Num_sol()

# %%
plt.plot(m1.rn, m1.α, label = '$\omega=1$')
plt.plot(m2.rn, m2.α, label = '$\omega=3$')
plt.plot(m3.rn, m3.α, label = '$\omega=7$')
plt.plot(m4.rn, m4.α, label = '$\omega=9$')
#plt.text(5, .51,'$0π$')
plt.xlabel('$r$', fontsize=22)
#plt.xlim([0, 80])
#plt.ylim([-1, 28])
plt.title('α(r) for fixed α(0) = 19 but different $\omega=1$')
plt.legend(loc='center right')
#plt.show()
plt.savefig('w1.png', dpi =1000)
